# %%
import matplotlib.pyplot as plt
import random

# %%
from elias_code import *
from byte_based_code import *

# %% [markdown]
# # Variable-length integer encodings demonstrations

# %% [markdown]
# Demonstrations of Elias' coding and decoding

# %%
elias_code(127)
# Out:
# '1011011111110'

# %%
elias_code((127,31,32))
# Out:
# '101101111111010100111110101011000000'

# %%
elias_decode(elias_code(127))
# Out:
# [127]

# %%
elias_decode(elias_code((127,31,32)))
# Out:
# [127, 31, 32]

# %% [markdown]
# Demonstration of the byte-based code

# %%
byte_based_decode(byte_based_code([12,43,0], 3), 3)
# Out:
# [12, 43, 0]

# %%
byte_based_code(43,3)
# Out:
# '010010011111'

# %% [markdown]
# # Comparisons with different lengths

# %%
# %matplotlib notebook

max_length = 5000

lengths = range(max_length)
byte_lengths = [4,16,64,256]
numbers = ['1'+''.join(random.choices(['0', '1'], k=length)) for length in lengths]
byte_based = [[len(byte_based_code(number, byte_length)) for number in numbers] for byte_length in byte_lengths]
elias = [len(elias_code(number)) for number in numbers]

plt.figure(figsize=(10,7))
plt.plot(elias, label='Elias code')
for length, data in zip(byte_lengths, byte_based):
    plt.plot(data, label=f'Byte = {length}')

plt.plot(lengths, label='Identity (upper bound)')
    
plt.legend(loc=2)
plt.ylabel('Code length')
plt.xlabel('Binary number length')
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">
# Text(0.5, 0, 'Binary number length')
